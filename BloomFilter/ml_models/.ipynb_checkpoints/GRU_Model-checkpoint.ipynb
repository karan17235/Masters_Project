# %%
import json
import random
import numpy as np
import math
import datetime
from collections import Counter
import matplotlib as pyplot

# Scikit-learn imports
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# Tensorflow and keras imports
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K

# plot training history
import matplotlib.pyplot as plt

# %%
K.clear_session()
tf.compat.v1.reset_default_graph()

# %%
def data():
    maxlen = 50
    embedding_size = 50
    pca_embedding_dim = 16
    
    # importing the glove embeddings path 
    embeddings_path = '../data/glove.6B.50d-char.txt'
    
    # Indexing character vectors using glove word vectors
    embedding_vectors = {}
    with open(embeddings_path, 'r') as f:
        for line in f:
            line_split = line.strip().split(" ")
            vec = np.array(line_split[1:], dtype=float)
            char = line_split[0]
            embedding_vectors[char] = vec
#     print('Found %s char vectors.' % len(embedding_vectors))
    
    # loading the dataset
    with open('../data/dataset.json', 'r') as f:
        dataset = json.load(f)
        positives = dataset['positives']
        negatives = dataset['negatives']
    
    # dividing the dataset to make small models
    data_fraction = 1
    positives = positives[:int(data_fraction * len(positives))]
    negatives = negatives[:int(data_fraction * len(negatives))]
    print("Total Dataset: ", len(positives+negatives))
    
    # Dividing the negatives dataset between train, dev and test
    negatives_train = negatives[0: int(len(negatives) * .8)]
    negatives_dev = negatives[int(len(negatives) * .8): int(len(negatives) * .9)]
    negatives_test = negatives[int(len(negatives) * .9): ]
    print("Split sizes:")
    print(len(positives), len(negatives_train), len(negatives_dev), len(negatives_test))
    
    # Shuffling the data
    a = [(i, 0) for i in negatives_train]
    b = [(i, 1) for i in positives]
    combined = a + b
    random.shuffle(combined)
    shuffled = list(zip(*combined))
    text_X = shuffled[0]
    labels = shuffled[1]
    
    # tokenizing the input url's
    tk = keras.preprocessing.text.Tokenizer(char_level=True)
    tk.fit_on_texts(text_X)
    
    # List the vocabulary
    word_index = tk.word_index
    vocab_size = len(word_index) + 1
#     print(vocab_size)
#     print(word_index)
    
    # integer encode the documents
    sequences = tk.texts_to_sequences(text_X)

    # pad documents to a max length of 4 words
    data = keras.preprocessing.sequence.pad_sequences(sequences, maxlen=maxlen) # by default the padding is post.
    labels = np.asarray(labels)
#     print('Shape of data tensor:', data.shape)
#     print('Shape of label tensor:', labels.shape)
    
    # Dividing the dataset into train and test.
    X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)
    
    # split the training data into a training set and a validation set
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)
    print(len(X_train))
    print(len(X_val))
    
    # create a weight matrix for words in training docs
#     print('Preparing embedding matrix.')
    embedding_matrix = np.zeros((vocab_size, embedding_size))
    for char, i in word_index.items():
        embedding_vector = embedding_vectors.get(char)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
#     print(embedding_matrix.shape)
    
    # PCA Embedding dimension
    pca = PCA(n_components = pca_embedding_dim)
    pca.fit(embedding_matrix[1:])
    embedding_matrix_pca = np.array(pca.transform(embedding_matrix[1:]))
    embedding_matrix_pca = np.insert(embedding_matrix_pca, 0, 0, axis=0)
    print("PCA matrix created")
    
    return (X_train, X_test, y_train, y_test, X_val, y_val, embedding_matrix_pca, maxlen, vocab_size, word_index,
            positives, negatives_train, negatives_dev, negatives_test)

# %%
def create_model(embedding_matrix, vocab_size, maxlen):
    model = keras.Sequential([
            keras.layers.Embedding(vocab_size, 16, input_length=maxlen, weights=[embedding_matrix]),
#             keras.layers.GRU(16, dropout=0.1, kernel_regularizer=keras.regularizers.l2(1e-4)),
            keras.layers.GRU(16, return_sequences=False),
            keras.layers.Dense(8, activation='relu'),
            keras.layers.Dense(1, activation = 'sigmoid')
    ])

    optimizer = keras.optimizers.Adam(lr = 0.001, decay = 0.0001)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    earlyStopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=1, min_delta = 0.001)
    file_path = '../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5'
    checkpoint = keras.callbacks.ModelCheckpoint(filepath=file_path, verbose=1, save_best_only=True)
    callbacks_list = [earlyStopping, checkpoint]
    print(model.summary())
    return model, callbacks_list

# %%
before_dataset = datetime.datetime.now()
(X_train, X_test, y_train, y_test, X_val, y_val, embedding_matrix, maxlen, vocab_size, word_index,
    positives, negatives_train, negatives_dev, negatives_test) = data()
after_dataset = datetime.datetime.now()
delta_dataset = after_dataset - before_dataset
print("Data Preprocessing time:", delta_dataset)
# Out:
# Total Dataset:  2926705
# Split sizes:
# 1491178 1148421 143553 143553
# 1900511
# 211168
# PCA matrix created
# Data Preprocessing time: 0:01:10.202031

# %%
training_start = datetime.datetime.now()
model, callbacks_list = create_model(embedding_matrix, vocab_size, maxlen)
history = model.fit(X_train, y_train, batch_size = 7168, epochs = 50, verbose=2, 
          validation_data=(X_val, y_val), callbacks = callbacks_list)
training_stop = datetime.datetime.now()
delta_training = training_stop - training_start
print("Model training time:", delta_training)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 50, 16)            624
# _________________________________________________________________
# gru_3 (GRU)                  (None, 16)                1632
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 2,401
# Trainable params: 2,401
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
#
# Epoch 00001: val_loss improved from inf to 0.54148, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.6023 - accuracy: 0.6486 - val_loss: 0.5415 - val_accuracy: 0.6998
# Epoch 2/50
#
# Epoch 00002: val_loss improved from 0.54148 to 0.50230, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.5199 - accuracy: 0.7202 - val_loss: 0.5023 - val_accuracy: 0.7340
# Epoch 3/50
#
# Epoch 00003: val_loss improved from 0.50230 to 0.47436, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4886 - accuracy: 0.7457 - val_loss: 0.4744 - val_accuracy: 0.7566
# Epoch 4/50
#
# Epoch 00004: val_loss improved from 0.47436 to 0.45398, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4637 - accuracy: 0.7637 - val_loss: 0.4540 - val_accuracy: 0.7697
# Epoch 5/50
#
# Epoch 00005: val_loss improved from 0.45398 to 0.43940, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4476 - accuracy: 0.7744 - val_loss: 0.4394 - val_accuracy: 0.7796
# Epoch 6/50
#
# Epoch 00006: val_loss improved from 0.43940 to 0.42933, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.4360 - accuracy: 0.7816 - val_loss: 0.4293 - val_accuracy: 0.7866
# Epoch 7/50
#
# Epoch 00007: val_loss improved from 0.42933 to 0.42133, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4269 - accuracy: 0.7874 - val_loss: 0.4213 - val_accuracy: 0.7920
# Epoch 8/50
#
# Epoch 00008: val_loss improved from 0.42133 to 0.41566, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4189 - accuracy: 0.7928 - val_loss: 0.4157 - val_accuracy: 0.7960
# Epoch 9/50
#
# Epoch 00009: val_loss improved from 0.41566 to 0.40825, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4122 - accuracy: 0.7975 - val_loss: 0.4083 - val_accuracy: 0.8008
# Epoch 10/50
#
# Epoch 00010: val_loss improved from 0.40825 to 0.40307, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.4058 - accuracy: 0.8016 - val_loss: 0.4031 - val_accuracy: 0.8042
# Epoch 11/50
#
# Epoch 00011: val_loss improved from 0.40307 to 0.39809, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.4002 - accuracy: 0.8052 - val_loss: 0.3981 - val_accuracy: 0.8068
# Epoch 12/50
#
# Epoch 00012: val_loss improved from 0.39809 to 0.39269, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3952 - accuracy: 0.8085 - val_loss: 0.3927 - val_accuracy: 0.8104
# Epoch 13/50
#
# Epoch 00013: val_loss improved from 0.39269 to 0.38858, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3910 - accuracy: 0.8116 - val_loss: 0.3886 - val_accuracy: 0.8130
# Epoch 14/50
#
# Epoch 00014: val_loss improved from 0.38858 to 0.38473, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3871 - accuracy: 0.8140 - val_loss: 0.3847 - val_accuracy: 0.8156
# Epoch 15/50
#
# Epoch 00015: val_loss improved from 0.38473 to 0.38363, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3838 - accuracy: 0.8160 - val_loss: 0.3836 - val_accuracy: 0.8157
# Epoch 16/50
#
# Epoch 00016: val_loss improved from 0.38363 to 0.37867, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3806 - accuracy: 0.8179 - val_loss: 0.3787 - val_accuracy: 0.8197
# Epoch 17/50
#
# Epoch 00017: val_loss improved from 0.37867 to 0.37571, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3775 - accuracy: 0.8197 - val_loss: 0.3757 - val_accuracy: 0.8214
# Epoch 18/50
#
# Epoch 00018: val_loss improved from 0.37571 to 0.37316, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3750 - accuracy: 0.8213 - val_loss: 0.3732 - val_accuracy: 0.8224
# Epoch 19/50
#
# Epoch 00019: val_loss improved from 0.37316 to 0.37112, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3724 - accuracy: 0.8228 - val_loss: 0.3711 - val_accuracy: 0.8241
# Epoch 20/50
#
# Epoch 00020: val_loss improved from 0.37112 to 0.36885, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3701 - accuracy: 0.8242 - val_loss: 0.3689 - val_accuracy: 0.8254
# Epoch 21/50
#
# Epoch 00021: val_loss improved from 0.36885 to 0.36880, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3679 - accuracy: 0.8256 - val_loss: 0.3688 - val_accuracy: 0.8255
# Epoch 22/50
#
# Epoch 00022: val_loss improved from 0.36880 to 0.36491, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.3659 - accuracy: 0.8267 - val_loss: 0.3649 - val_accuracy: 0.8272
# Epoch 23/50
#
# Epoch 00023: val_loss improved from 0.36491 to 0.36420, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3641 - accuracy: 0.8278 - val_loss: 0.3642 - val_accuracy: 0.8281
# Epoch 24/50
#
# Epoch 00024: val_loss improved from 0.36420 to 0.36246, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.3623 - accuracy: 0.8288 - val_loss: 0.3625 - val_accuracy: 0.8293
# Epoch 25/50
#
# Epoch 00025: val_loss improved from 0.36246 to 0.36002, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3607 - accuracy: 0.8298 - val_loss: 0.3600 - val_accuracy: 0.8303
# Epoch 26/50
#
# Epoch 00026: val_loss improved from 0.36002 to 0.35904, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3592 - accuracy: 0.8307 - val_loss: 0.3590 - val_accuracy: 0.8307
# Epoch 27/50
#
# Epoch 00027: val_loss improved from 0.35904 to 0.35822, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3576 - accuracy: 0.8316 - val_loss: 0.3582 - val_accuracy: 0.8313
# Epoch 28/50
#
# Epoch 00028: val_loss improved from 0.35822 to 0.35635, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3565 - accuracy: 0.8322 - val_loss: 0.3563 - val_accuracy: 0.8323
# Epoch 29/50
#
# Epoch 00029: val_loss improved from 0.35635 to 0.35503, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3551 - accuracy: 0.8331 - val_loss: 0.3550 - val_accuracy: 0.8330
# Epoch 30/50
#
# Epoch 00030: val_loss improved from 0.35503 to 0.35358, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3540 - accuracy: 0.8338 - val_loss: 0.3536 - val_accuracy: 0.8337
# Epoch 31/50
#
# Epoch 00031: val_loss improved from 0.35358 to 0.35262, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3527 - accuracy: 0.8346 - val_loss: 0.3526 - val_accuracy: 0.8345
# Epoch 32/50
#
# Epoch 00032: val_loss improved from 0.35262 to 0.35120, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3514 - accuracy: 0.8353 - val_loss: 0.3512 - val_accuracy: 0.8353
# Epoch 33/50
#
# Epoch 00033: val_loss improved from 0.35120 to 0.35027, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.3506 - accuracy: 0.8356 - val_loss: 0.3503 - val_accuracy: 0.8358
# Epoch 34/50
#
# Epoch 00034: val_loss improved from 0.35027 to 0.34902, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3494 - accuracy: 0.8364 - val_loss: 0.3490 - val_accuracy: 0.8360
# Epoch 35/50
#
# Epoch 00035: val_loss improved from 0.34902 to 0.34823, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.3484 - accuracy: 0.8370 - val_loss: 0.3482 - val_accuracy: 0.8370
# Epoch 36/50
#
# Epoch 00036: val_loss improved from 0.34823 to 0.34725, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3477 - accuracy: 0.8376 - val_loss: 0.3472 - val_accuracy: 0.8375
# Epoch 37/50
#
# Epoch 00037: val_loss improved from 0.34725 to 0.34669, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3465 - accuracy: 0.8382 - val_loss: 0.3467 - val_accuracy: 0.8381
# Epoch 38/50
#
# Epoch 00038: val_loss improved from 0.34669 to 0.34556, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3456 - accuracy: 0.8387 - val_loss: 0.3456 - val_accuracy: 0.8385
# Epoch 39/50
#
# Epoch 00039: val_loss improved from 0.34556 to 0.34512, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.3449 - accuracy: 0.8391 - val_loss: 0.3451 - val_accuracy: 0.8393
# Epoch 40/50
#
# Epoch 00040: val_loss improved from 0.34512 to 0.34400, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 48s - loss: 0.3440 - accuracy: 0.8397 - val_loss: 0.3440 - val_accuracy: 0.8397
# Epoch 41/50
#
# Epoch 00041: val_loss improved from 0.34400 to 0.34335, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3432 - accuracy: 0.8402 - val_loss: 0.3434 - val_accuracy: 0.8403
# Epoch 42/50
#
# Epoch 00042: val_loss improved from 0.34335 to 0.34240, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3424 - accuracy: 0.8406 - val_loss: 0.3424 - val_accuracy: 0.8407
# Epoch 43/50
#
# Epoch 00043: val_loss improved from 0.34240 to 0.34232, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3417 - accuracy: 0.8410 - val_loss: 0.3423 - val_accuracy: 0.8407
# Epoch 44/50
#
# Epoch 00044: val_loss improved from 0.34232 to 0.34083, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3411 - accuracy: 0.8414 - val_loss: 0.3408 - val_accuracy: 0.8417
# Epoch 45/50
#
# Epoch 00045: val_loss did not improve from 0.34083
# 310/310 - 47s - loss: 0.3403 - accuracy: 0.8419 - val_loss: 0.3414 - val_accuracy: 0.8414
# Epoch 46/50
#
# Epoch 00046: val_loss improved from 0.34083 to 0.33956, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3397 - accuracy: 0.8422 - val_loss: 0.3396 - val_accuracy: 0.8425
# Epoch 47/50
#
# Epoch 00047: val_loss improved from 0.33956 to 0.33940, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3392 - accuracy: 0.8426 - val_loss: 0.3394 - val_accuracy: 0.8426
# Epoch 48/50
#
# Epoch 00048: val_loss improved from 0.33940 to 0.33858, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3384 - accuracy: 0.8430 - val_loss: 0.3386 - val_accuracy: 0.8434
# Epoch 49/50
#
# Epoch 00049: val_loss improved from 0.33858 to 0.33795, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3379 - accuracy: 0.8433 - val_loss: 0.3379 - val_accuracy: 0.8435
# Epoch 50/50
#
# Epoch 00050: val_loss improved from 0.33795 to 0.33768, saving model to ../model_weights/keras_weights_GRU_full_dataset_without_pca.hdf5
# 310/310 - 47s - loss: 0.3373 - accuracy: 0.8436 - val_loss: 0.3377 - val_accuracy: 0.8435
# Model training time: 0:39:36.369624

# %% [markdown]
# ### Plotting graphs for each epoch.

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# evaluate the model
before_train_evaluation = datetime.datetime.now()
train_loss, train_acc = model.evaluate(X_train, y_train, verbose=0)
after_train_evaluation = datetime.datetime.now()
delta_train_evaluation = after_train_evaluation - before_train_evaluation
print("Model evaluation time on training data", delta_train_evaluation)

before_test_evaluation = datetime.datetime.now()
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
after_test_evaluation = datetime.datetime.now()
delta_test_evaluation = after_test_evaluation - before_test_evaluation
print("Model evaluation time on testing data", delta_test_evaluation)

print('Training Loss: %.3f, Testing loss: %.3f' % (train_loss, test_loss) )
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# Out:
# Model evaluation time on training data 0:04:16.624819
# Model evaluation time on testing data 0:01:11.221490
# Training Loss: 0.337, Testing loss: 0.340
# Train: 0.844, Test: 0.843

# %%
plt.plot(history.history['loss'], label='training_loss')
plt.plot(history.history['val_loss'], label='validation_loss')
plt.legend()
plt.show()

# %%
# Saving the model and loading the saved model

model.save('../diagram/full_GRU_PCA.h5')

# model.save('../saved_models/full_model_GRU_with_pca.h5')
#model = keras.models.load_model('../saved_models/gru_new.h5')

# %%
import gc
gc.collect()
# Out:
# 123831

# %%
def predict(text_x):
    x = np.zeros((1, maxlen), dtype=np.int)
    offset = max(maxlen - len(text_x), 0)
    for t, char in enumerate(text_x):
        if t >= maxlen:
            break
        x[0, t + offset] = word_index[char]
    pred = model.predict(x)
    return pred[0][0]


# Like predict, but you pass in an array of URLs, and it is all
# vectorized in one step, making it more efficient
def predicts(text_X):
    X = np.zeros((len(text_X), maxlen), dtype=np.int)
    for i in range(len(text_X)):
        offset = max(maxlen - len(text_X[i]), 0)
        for t, char in enumerate(text_X[i]):
            if t >= maxlen:
                break
            X[i, t + offset] = word_index[char]
    preds = [pred[0] for pred in model.predict(X)]
    return preds

# %%
import timeit

start = timeit.default_timer()
pre = predict(positives[0])
end = timeit.default_timer()
print("Prediction time", (end - start))

# %%
# Model Evaluation
# define a threshold value so that values below threshold will be classified as false_positive
threshold = 0.5

def evaluate_model(positives, negatives_train, negatives_dev, negatives_test, threshold):
    false_negatives = 0.0
    preds = predicts(positives)
    for pred in preds:
        if pred <= threshold:
            false_negatives += 1
    print(false_negatives / len(positives), "false negatives for positives set.")

    false_positives_train = 0.0
    preds = predicts(negatives_train)
    for pred in preds:
        if pred > threshold:
            false_positives_train += 1

    false_positives_dev = 0.0
    preds = predicts(negatives_dev)
    for pred in preds:
        if pred > threshold:
            false_positives_dev += 1

    false_positives_test = 0.0
    preds = predicts(negatives_test)
    for pred in preds:
        if pred > threshold:
            false_positives_test += 1

    print(false_positives_train / len(negatives_train), "false positive rate for negative train.")
    print(false_positives_dev / len(negatives_dev), "false positive rate for negative dev.")
    print(false_positives_test / len(negatives_test), "false positive rate for negative test.")

evaluate_model(positives, negatives_train, negatives_dev, negatives_test, threshold)

# %%
# Getting predictions on negative_dev set to find a suitable threshold value.

# defining the false positive rate which we can change.
fp_rate = 0.01

print("Getting threshold for fp_rate", fp_rate)
preds = predicts(negatives_dev)
preds.sort()
fp_index = math.ceil((len(negatives_dev) * (1 - fp_rate)))
threshold = preds[fp_index]

print("Using threshold", threshold) 

evaluate_model(positives, negatives_train, negatives_dev, negatives_test, threshold)

# %% [markdown]
# ### Bloom Filter

# %%
##  Adapted from https://www.geeksforgeeks.org/bloom-filters-introduction-and-python-implementation/ 

import math 
import mmh3 
from bitarray import bitarray 

class BloomFilter(object): 

    ''' 
    Class for Bloom filter, using murmur3 hash function 
    '''

    def __init__(self, items_count,fp_prob): 
        ''' 
        items_count : int 
            Number of items expected to be stored in bloom filter 
        fp_prob : float 
            False Positive probability in decimal 
        '''
        # False posible probability in decimal 
        self.fp_prob = fp_prob 

        # Size of bit array to use 
        self.size = self.get_size(items_count,fp_prob) 

        # number of hash functions to use 
        self.hash_count = self.get_hash_count(self.size,items_count) 

        # Bit array of given size 
        self.bit_array = bitarray(self.size) 
        
        # Return the size of bitarray in bytes
        self.byte_size = self.bit_array.length()

        # initialize all bits as 0 
        self.bit_array.setall(0) 

    def add(self, item): 
        ''' 
        Add an item in the filter 
        '''
        digests = [] 
        for i in range(self.hash_count): 

            # create digest for given item. 
            # i work as seed to mmh3.hash() function 
            # With different seed, digest created is different 
            digest = mmh3.hash(item,i) % self.size 
            digests.append(digest) 

            # set the bit True in bit_array 
            self.bit_array[digest] = True

    def check(self, item): 
        ''' 
        Check for existence of an item in filter 
        '''
        for i in range(self.hash_count): 
            digest = mmh3.hash(item,i) % self.size 
            if self.bit_array[digest] == False: 

                # if any of bit is False then,its not present 
                # in filter 
                # else there is probability that it exist 
                return False
        return True

    @classmethod
    def get_size(self,n,p): 
        ''' 
        Return the size of bit array(m) to used using 
        following formula 
        m = -(n * lg(p)) / (lg(2)^2) 
        n : int 
            number of items expected to be stored in filter 
        p : float 
            False Positive probability in decimal 
        '''
        m = -(n * math.log(p))/(math.log(2)**2) 
        return int(m)
    
    @classmethod
    def get_hash_count(self, m, n): 
        ''' 
        Return the hash function(k) to be used using 
        following formula 
        k = (m/n) * lg(2) 

        m : int 
			size of bit array 
		n : int 
			number of items expected to be stored in filter 
		'''
        k = (m/n) * math.log(2) 
        return int(k)

# %% [markdown]
# ### Defining Deep Bloom Model

# %%
# Defining the threshold value
fp_rate = 0.01
print("Getting threshold for fp_rate", fp_rate)
preds = predicts(negatives_dev)
preds.sort()
fp_index = math.ceil((len(negatives_dev) * (1 - fp_rate/2)))
threshold = preds[fp_index]
print("The threhold value to use is:", threshold)

# %%
def create_bloom_filter(data):
    print("Creating bloom filter")
    false_negatives = []
    # calling the predicts function 
    preds = predicts(data)
    for i in range(len(data)):
        if preds[i] <= threshold:
            false_negatives.append(data[i])
    print("Number of false negatives at bloom time", len(false_negatives))
    bloom_filter = BloomFilter(len(false_negatives), fp_rate / 2)
    for fn in false_negatives:
        bloom_filter.add(fn)
    print("Created bloom filter")
    return bloom_filter

bloom_filter = create_bloom_filter(positives)

# %%
# Function to predict the output from the machine learning model
def predict(text_x):
    x = np.zeros((1, maxlen), dtype=np.int)
    offset = max(maxlen - len(text_x), 0)
    for t, char in enumerate(text_x):
        if t >= maxlen:
            break
        x[0, t + offset] = word_index[char]
    pred = model.predict(x)
    return pred[0][0]


def check_item(item):
    if predict(item) > threshold:
        return True
    return bloom_filter.check(item)

# %% [markdown]
# #### Test Deep Bloom Model

# %%
print("Bloom filter bits needed", bloom_filter.size)
print("Bloom fiter size in bytes", (bloom_filter.byte_size)/8)
print("Hash functions needed", bloom_filter.hash_count)
    
false_positives = 0.0
print(len(negatives_test))
for neg in negatives_test:
    if check_item(neg):
        false_positives += 1
print("Test false positive rate: ", str(false_positives / len(negatives_test)))
